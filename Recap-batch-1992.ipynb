# %% [markdown]
# # From Data to Viz
#
# The purpose of this Recap is to choose the right data visualization for a given question on a dataset.
#
# (Freely inspired from https://www.data-to-viz.com/)
#
# Let's start by running the following cell:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## A - Penguins 🐧
#
#
# Let's explore the Seaborn [**Penguins**](https://github.com/mwaskom/seaborn-data/blob/master/penguins.csv) dataset, quite known in the Machine Learning beginners community.
#
# Here's a nice picture to get used to the vocabulary around these Penguins:
#
# <img src="https://wagon-public-datasets.s3.amazonaws.com/05-Machine-Learning/gentoo.png" height=700>

# %%
penguin_df = sns.load_dataset('penguins')
penguin_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %% [markdown]
# ---
#
# ### ❓ 1 - Counting Species
#
# How many different species are there in the dataset? Use a Seaborn plot to visualize their relative importance.

# %%
ax = sns.countplot(penguin_df, x="species")
ax.set_title("count per species")
# Out:
# Text(0.5, 1.0, 'count per species')

# %% [markdown]
# ---
# ### ❓ 2 - Body mass distribution
#
# Let's see if the body mass distribution in the dataset is normal or not. Use a Seaborn plot to visualize the distribution of the `body_mass_g` column of `penguin_df`.

# %%
sns.histplot(x="body_mass_g", kde=True, bins=20, data=penguin_df)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
ser = penguin_df["body_mass_g"]
ser

sns.histplot(ser)
sns.histplot(penguin_df["body_mass_g"])
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %% [markdown]
# ---
# ### ❓ 3 - Relationships of Numerical variables
#
# Let's use a Seaborn plot to quickly get a sense of the `(x, y)` relationship of all couples of numerical columns ('bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', etc.). You should use a plot which will draw 16 subplots in one line of code!

# %%
sns.pairplot(penguin_df, hue="island", diag_kind="kde")

# %% [markdown]
# ---
#
# ### ❓ 4 - Numerical + Categorical
#
# We learned a lot about this sample of penguins:
# - `bill_length_mm` seems to be an important dimension to identify penguins
# - some of their dimensions are correlated
# - there are 3 species
#
# How can you visualize the differences between the 3 species of  penguins with different colors? Using Seaborn, write some code to get some helpful scatterplots and/or violin-plots (we want to use the `species` as colors to better identify groups!).

# %%
penguin_df

# %%
sns.catplot(penguin_df, y="species", x="body_mass_g", kind="box")

# %%
# YOUR CODE HERE

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## B - Maps 🗺
#
#
# 😱 **Imagine a world where people can't go further than 100km from home**. How can you help them to know where they can go?
#
# For this second part of the Recap, we will be using the [`folium`](https://python-visualization.github.io/folium/) package, a wrapper around the [`Leaflet`](https://leafletjs.com/) JavaScript library.

# %%
# !pip install --quiet folium

# %% [markdown]
# Now import Folium:

# %%
import folium

# %% [markdown]
# ---
#
# ### ❓ 1 - Draw your first map
#
# The goal of this first question is to:
#
# - Draw a map centered at specific coordinates (check out [gps-coorinates.net](https://www.gps-coordinates.net/))
# - Put a marker at that specific point
# - Draw a circle of 100km centered at specific point
#
# Check out the [`folium` Quickstart](https://python-visualization.github.io/folium/quickstart.html), you should find all the code examples you need, good luck!

# %%
coordinates = [48.8649224, 2.3800903] # 16 Villa Gaudelet, Paris

m = folium.Map(
    location=coordinates,
    zoom_start = 8
)

folium.Marker(
    location=coordinates,
    tooltip="Click me!",
    popup="Timberline Lodge",
    icon=folium.Icon(color="green"),
).add_to(m)

radius = 100_000
folium.Circle(
    location=coordinates,
    radius=radius,
    color="black",
    weight=1,
    fill_opacity=0.2,
    opacity=1,
    fill_color="blue",
    fill=False,  # gets overridden by fill_color
    popup="{} meters".format(radius),
    tooltip="I am in meters",
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab9d61b2402d5c4856d1333baf41093d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab9d61b2402d5c4856d1333baf41093d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab9d61b2402d5c4856d1333baf41093d = L.map(
#                 &quot;map_ab9d61b2402d5c4856d1333baf41093d&quot;,
#                 {
#                     center: [48.8649224, 2.3800903],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7da460ed280dfd8206be1f428ea6d2d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e7da460ed280dfd8206be1f428ea6d2d.addTo(map_ab9d61b2402d5c4856d1333baf41093d);
#
#
#             var marker_c4bed95afdc8adbc25010dce2fd3442f = L.marker(
#                 [48.8649224, 2.3800903],
#                 {
# }
#             ).addTo(map_ab9d61b2402d5c4856d1333baf41093d);
#
#
#             var icon_9d692fcf60e1c4c73b6cbd6635e8faaa = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_fe5dedb1d53bd78379fccdda5938fa4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff9ea8523687604eb980e3d1ad5e4523 = $(`&lt;div id=&quot;html_ff9ea8523687604eb980e3d1ad5e4523&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timberline Lodge&lt;/div&gt;`)[0];
#                 popup_fe5dedb1d53bd78379fccdda5938fa4d.setContent(html_ff9ea8523687604eb980e3d1ad5e4523);
#
#
#
#         marker_c4bed95afdc8adbc25010dce2fd3442f.bindPopup(popup_fe5dedb1d53bd78379fccdda5938fa4d)
#         ;
#
#
#
#
#             marker_c4bed95afdc8adbc25010dce2fd3442f.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_c4bed95afdc8adbc25010dce2fd3442f.setIcon(icon_9d692fcf60e1c4c73b6cbd6635e8faaa);
#
#
#             var circle_df161e7a6945a67bc882c4fb5d1935d9 = L.circle(
#                 [48.8649224, 2.3800903],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 100000, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_ab9d61b2402d5c4856d1333baf41093d);
#
#
#         var popup_5758488b61c3710b7211cb45a16ed94b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aba16eb7a45a339c69799b9ddf0d0049 = $(`&lt;div id=&quot;html_aba16eb7a45a339c69799b9ddf0d0049&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;100000 meters&lt;/div&gt;`)[0];
#                 popup_5758488b61c3710b7211cb45a16ed94b.setContent(html_aba16eb7a45a339c69799b9ddf0d0049);
#
#
#
#         circle_df161e7a6945a67bc882c4fb5d1935d9.bindPopup(popup_5758488b61c3710b7211cb45a16ed94b)
#         ;
#
#
#
#
#             circle_df161e7a6945a67bc882c4fb5d1935d9.bindTooltip(
#                 `&lt;div&gt;
#                      I am in meters
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ---
#
# ### ❓ 2 - Build a User-Friendly tool
#
# The problem of the previous code is that we need to manually convert an address into the GPS coordinates. Let's implement a program so that user can specify their plain text address and get the map drawn for that point:
#
# ```python
# draw_100km_map("138 Kingsland Rd, London E2 8DY")
# ```
#
# 💡 Hint: You can use the [Nominatim Search API](https://nominatim.org/release-docs/latest/api/Search/) to implement a `geocode(address)` function which returns a list of `[lat, lng]` coordinates.

# %% [markdown]
# 💡 Getting a 403 Forbidden error? The Nominatim API is free to use, but doesn't accept the default headers that most http packages use. So you have to provide your own headers when making the request. Giving a name for your app in `User-Agent` should be enough.

# %%
# !curl "https://nominatim.openstreetmap.org/search?q=20 rue des capucins, Lyon&format=json"
# Out:
# curl: (3) URL rejected: Malformed input to a URL function

# %%
import requests

url = "https://nominatim.openstreetmap.org/search"

response = requests.get(url, params = {"q": "rue des capucins, Lyon", "format": "json"}, headers = {'User-Agent': 'test_app'})
response.json()[0]
# Out:
# {'place_id': 86234136,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 5120893,
#  'lat': '45.7694176',
#  'lon': '4.8344169',
#  'class': 'highway',
#  'type': 'residential',
#  'place_rank': 26,
#  'importance': 0.05341247196154723,
#  'addresstype': 'road',
#  'name': 'Rue des Capucins',
#  'display_name': 'Rue des Capucins, Terreaux, Lyon 1er Arrondissement, Lyon, Métropole de Lyon, Rhône, Auvergne-Rhône-Alpes, France métropolitaine, 69001, France',
#  'boundingbox': ['45.7691399', '45.7696890', '4.8330233', '4.8358118']}

# %%
def draw_100km_map(user_input):
    # user inout > coordonnées 
    response = requests.get(url, params = {"q": user_input, "format": "json"}, headers = {'User-Agent': 'test_app'})
    response = response.json()[0]

    coordinates = [response['lat'],response['lon']]

    
    # injecter coord dans le code poyur générer map
    m = folium.Map(
        location=coordinates,
        zoom_start = 8
    )
    
    folium.Marker(
        location=coordinates,
        tooltip="Click me!",
        popup="Timberline Lodge",
        icon=folium.Icon(color="green"),
    ).add_to(m)
    
    radius = 100_000
    folium.Circle(
        location=coordinates,
        radius=radius,
        color="black",
        weight=1,
        fill_opacity=0.2,
        opacity=1,
        fill_color="blue",
        fill=False,  # gets overridden by fill_color
        popup="{} meters".format(radius),
        tooltip="I am in meters",
    ).add_to(m)

    return m

# %% [markdown]
# The interactive tool:

# %%
address = input("Input your address > ")
draw_100km_map(address)
# Out:
# Input your address >  Narnia
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f762dd7639454b2f95e405d5ee237da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f762dd7639454b2f95e405d5ee237da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f762dd7639454b2f95e405d5ee237da = L.map(
#                 &quot;map_0f762dd7639454b2f95e405d5ee237da&quot;,
#                 {
#                     center: [42.5195891, 12.5152257],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2483379a52b2bbd16d4b4a16a15320b3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2483379a52b2bbd16d4b4a16a15320b3.addTo(map_0f762dd7639454b2f95e405d5ee237da);
#
#
#             var marker_6c8e539bf1b0b4731c66585ede6df452 = L.marker(
#                 [42.5195891, 12.5152257],
#                 {
# }
#             ).addTo(map_0f762dd7639454b2f95e405d5ee237da);
#
#
#             var icon_3a0e134de055d760c2a5e472b666306b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ff10e7c3e5a7e8ebfc51b31195312c64 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab5e8e7c4e86a81252654f55a168ea89 = $(`&lt;div id=&quot;html_ab5e8e7c4e86a81252654f55a168ea89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timberline Lodge&lt;/div&gt;`)[0];
#                 popup_ff10e7c3e5a7e8ebfc51b31195312c64.setContent(html_ab5e8e7c4e86a81252654f55a168ea89);
#
#
#
#         marker_6c8e539bf1b0b4731c66585ede6df452.bindPopup(popup_ff10e7c3e5a7e8ebfc51b31195312c64)
#         ;
#
#
#
#
#             marker_6c8e539bf1b0b4731c66585ede6df452.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_6c8e539bf1b0b4731c66585ede6df452.setIcon(icon_3a0e134de055d760c2a5e472b666306b);
#
#
#             var circle_54e53ba214aaa20d21c23a271ee68cb9 = L.circle(
#                 [42.5195891, 12.5152257],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 100000, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_0f762dd7639454b2f95e405d5ee237da);
#
#
#         var popup_9d5eebedbfcf81d301ca899c7b6cd224 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48f77df9f554cee8e4eb50fbed2c53e2 = $(`&lt;div id=&quot;html_48f77df9f554cee8e4eb50fbed2c53e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;100000 meters&lt;/div&gt;`)[0];
#                 popup_9d5eebedbfcf81d301ca899c7b6cd224.setContent(html_48f77df9f554cee8e4eb50fbed2c53e2);
#
#
#
#         circle_54e53ba214aaa20d21c23a271ee68cb9.bindPopup(popup_9d5eebedbfcf81d301ca899c7b6cd224)
#         ;
#
#
#
#
#             circle_54e53ba214aaa20d21c23a271ee68cb9.bindTooltip(
#                 `&lt;div&gt;
#                      I am in meters
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
